# %%
import pandas as pd
import os

# %%
data=pd.read_csv("combined_data.csv", encoding='latin-1')

# %%
for item in list(data['Request Type'].unique()):
    print(item)
# Out:
# INC ERP Support
# Request for Reports
# Network Support
# INC Data & Analytics Support
# INC IT End-user Support
# Onboard New Employees
# Infrastructure & Cloud Support
# Request New Hardware
# Request New Software/License
# Request Access For
# ERP Support
# Data & Analytics Support
# IT End-user Support
# Cyber Security Support
# INC Cyber Security Support
# INC Infrastructure and Cloud Support
# Offboard an employee
# JIRA Feature request
# BlueTally Administration
# INC Network Support
# Digital Support
# Report a system problem
# Emailed request
# INC Digital Support
# Report broken hardware
# Request admin access
# Fix an account problem
# Request a new account
